# %% [markdown]
# # Encrypt Existing PDF (User + Owner Password) — pypdf

# %%
! pip uninstall pypdf -y
! pip install "pypdf==4.2.0"
# Out:
# Found existing installation: pypdf 6.4.1
# Uninstalling pypdf-6.4.1:
#   Successfully uninstalled pypdf-6.4.1
# Collecting pypdf==4.2.0
#   Downloading pypdf-4.2.0-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: typing_extensions>=4.0 in c:\users\nil\appdata\local\programs\python\python310\lib\site-packages (from pypdf==4.2.0) (4.14.0)
# Downloading pypdf-4.2.0-py3-none-any.whl (290 kB)
# Installing collected packages: pypdf
# Successfully installed pypdf-4.2.0
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\nil\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\nil\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\nil\appdata\local\programs\python\python310\lib\site-packages)

# %%
import pypdf

# %%
print(pypdf.__version__)
# Out:
# 4.2.0

# %%
from pypdf import PdfReader, PdfWriter

inp = "tt.pdf"
out = "encrypted.pdf"

reader = PdfReader(inp)
writer = PdfWriter()

for page in reader.pages:
    writer.add_page(page)

writer.encrypt(
    user_password="1234",
    owner_password="admin"
)

with open(out, "wb") as f:
    writer.write(f)

print("PDF encrypted successfully!")
# Out:
# PDF encrypted successfully!

# %% [markdown]
# ## Example 2 — Encrypt with Specific Permissions
#
# (Only printing allowed, copying disabled)

# %%
from pypdf import PdfReader, PdfWriter

reader = PdfReader("tt.pdf")
writer = PdfWriter()

for page in reader.pages:
    writer.add_page(page)

writer.encrypt(
    user_password="1234",
    owner_password="admin",
    permissions={
        "print": True,
        "copy": False,
        "extract": False,
        "annotate": False,
    }
)

with open("encrypted_permissions.pdf", "wb") as f:
    writer.write(f)

print("Encrypted with restricted permissions!")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [6], line 9
#       6 for page in reader.pages:
#       7     writer.add_page(page)
# ----> 9 writer.encrypt(
#      10     user_password="1234",
#      11     owner_password="admin",
#      12     permissions={
#      13         "print": True,
#      14         "copy": False,
#      15         "extract": False,
#      16         "annotate": False,
#      17     }
#      18 )
#      20 with open("encrypted_permissions.pdf", "wb") as f:
#      21     writer.write(f)
#
# TypeError: PdfWriter.encrypt() got an unexpected keyword argument 'permissions'

# %% [markdown]
# ## Example 3 — Strong Encryption (AES-256)

# %%
from pypdf import PdfReader, PdfWriter

reader = PdfReader("tt.pdf")
writer = PdfWriter()

for page in reader.pages:
    writer.add_page(page)

writer.encrypt(
    user_password="user123",
    owner_password="owner123",
    encryption_method="AES256"
)

with open("encrypted_AES256.pdf", "wb") as f:
    writer.write(f)

print("AES-256 encryption applied!")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [7], line 9
#       6 for page in reader.pages:
#       7     writer.add_page(page)
# ----> 9 writer.encrypt(
#      10     user_password="user123",
#      11     owner_password="owner123",
#      12     encryption_method="AES256"
#      13 )
#      15 with open("encrypted_AES256.pdf", "wb") as f:
#      16     writer.write(f)
#
# TypeError: PdfWriter.encrypt() got an unexpected keyword argument 'encryption_method'

# %% [markdown]
# ## Example 4 — Batch Encrypt all PDFs in a folder

# %%
import os
from pypdf import PdfReader, PdfWriter

folder = "pdfs/"
password = "batch123"

for file in os.listdir(folder):
    if file.endswith(".pdf"):
        reader = PdfReader(os.path.join(folder, file))
        writer = PdfWriter()
        
        for page in reader.pages:
            writer.add_page(page)
        
        writer.encrypt(password)
        
        enc_name = os.path.join(folder, "enc_" + file)
        with open(enc_name, "wb") as f:
            writer.write(f)

        print(f"Encrypted: {file}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [8], line 7
#       4 folder = "pdfs/"
#       5 password = "batch123"
# ----> 7 for file in os.listdir(folder):
#       8     if file.endswith(".pdf"):
#       9         reader = PdfReader(os.path.join(folder, file))
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'pdfs/'

# %% [markdown]
# ## Example 5 — Check if a PDF is Already Encrypted

# %%
from pypdf import PdfReader

reader = PdfReader("encrypted.pdf")

if reader.is_encrypted:
    print("PDF is encrypted")
else:
    print("PDF is NOT encrypted")
# Out:
# PDF is encrypted
